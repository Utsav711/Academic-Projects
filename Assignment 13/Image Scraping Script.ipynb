# %%
import pandas as pd
import selenium 
from selenium import webdriver
import time
from selenium.webdriver.common.keys import Keys
import re
import os
import requests

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from time import sleep 
from selenium.webdriver.support.wait import WebDriverWait as wait
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
import urllib
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Firefox()

# %% [markdown]
# ## Train Data: Amazon.in

# %% [markdown]
# ## Test Data: Flipkart.com

# %% [markdown]
# # Train Data

# %% [markdown]
# ## Sarees

# %%
url_saree='https://www.amazon.in/s?k=Sarees+%28women%29&ref=nb_sb_noss_2'
driver.get(url_saree)
time.sleep(2)

# %%
for page in range(4):
    sleep(3)
    url1 = []
    tags = driver.find_elements_by_xpath('//img[@class="s-image"]')
    sleep(1)
    for tag in tags:
        img_link= tag.get_attribute('src') 
        if tag is not None:
            if(img_link[0:4] == 'http'):
                url1.append(img_link)
    
    print(f"xx-------------------Page #{page+1}-------------------xx")
    
    for i in range(len(url1)):
        if i>=70:
            break
        response=requests.get(url1[i])
        file=open(r"C:\Users\utsav\Desktop\datatrained\internship\Assignment 13\train\saree "+str(page)+str(i)+".jpg","wb")
        file.write(response.content)
        print(f"Downloading Image #{i}")
        time.sleep(1.5)
    
        
    try:
        btn=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        btn.click()
        temp_count+=1
    except NoSuchElementException:
        pass
        time.sleep(1)
# Out:
# xx-------------------Page #1-------------------xx
# ...
# xx-------------------Page #2-------------------xx
# ...
# xx-------------------Page #3-------------------xx
# ...
# xx-------------------Page #4-------------------xx
# ...

# %% [markdown]
# ## Trousers (men)

# %%
url_tr='https://www.amazon.in/s?k=trousers+for+men&sprefix=trousers%2Caps%2C482&ref=nb_sb_ss_ts-doa-p_2_8'
driver.get(url_tr)

# %%
for page in range(4):
    url2 = []
    sleep(3)
    tags = driver.find_elements_by_xpath('//img[@class="s-image"]')
    sleep(1)
    for tag in tags:
        img_link= tag.get_attribute('src') 
        if tag is not None:
            if(img_link[0:4] == 'http'):
                url2.append(img_link)
    print(f"xx-------------------Page #{page}-------------------xx")
    
    for i in range(len(url2)):
        if i>=65:
            break
        response=requests.get(url2[i])
        file=open(r"C:\Users\utsav\Desktop\datatrained\internship\Assignment 13\train\trouser "+str(page)+str(i)+".jpg","wb")
        file.write(response.content)
        print(f"Downloading Image number {i}")
        time.sleep(1.5)
    
       
    try:
        btn=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        btn.click()
        
    except NoSuchElementException:
        pass
        time.sleep(1)
# Out:
# xx-------------------Page #0-------------------xx
# ...
# xx-------------------Page #1-------------------xx
# xx-------------------Page #2-------------------xx
# ...
# xx-------------------Page #3-------------------xx
# ...

# %%
# Running this again, as the number of images scraped were less than 200
url2 = []
sleep(3)
tags = driver.find_elements_by_xpath('//img[@class="s-image"]')
sleep(1)
for tag in tags:
    img_link= tag.get_attribute('src') 
    if tag is not None:
        if(img_link[0:4] == 'http'):
            url2.append(img_link)
print(f"xx-------------------Page #4-------------------xx")

for i in range(len(url2)):
    if i>=70:
        break
    response=requests.get(url2[i])
    file=open(r"C:\Users\utsav\Desktop\datatrained\internship\Assignment 13\train\trouser "+str(4)+str(i)+".jpg","wb")
    file.write(response.content)
    print(f"Downloading Image number {i}")
    time.sleep(1.5)


try:
    btn=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
    btn.click()

except NoSuchElementException:
    pass
    time.sleep(1)
# Out:
# xx-------------------Page #4-------------------xx
# ...

# %% [markdown]
# ## Jeans (men)

# %%
url_tr='https://www.amazon.in/s?k=Jeans+for+men&crid=1N1A958ZVFX9G&sprefix=jeans+for+men%2Caps%2C384&ref=nb_sb_noss'
driver.get(url_tr)

# %%
for page in range(4):
    url3 = []
    sleep(3)
    tags = driver.find_elements_by_xpath('//img[@class="s-image"]')
    sleep(1)
    for tag in tags:
        img_link= tag.get_attribute('src') 
        if tag is not None:
            if(img_link[0:4] == 'http'):
                url3.append(img_link)
                
    print(f"xx-------------------Page #{page+1}-------------------xx")
    
    for i in range(len(url3)):
        
        if i>=70:
            break
            
        response=requests.get(url3[i])
        file=open(r"C:\Users\utsav\Desktop\datatrained\internship\Assignment 13\train\jeans "+str(page)+str(i)+".jpg","wb")
        file.write(response.content)
        print(f"Downloading Image number {i}")
        time.sleep(1.5)
    
       
    try:
        btn=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        btn.click()
        
    except NoSuchElementException:
        pass
        time.sleep(1)
# Out:
# xx-------------------Page #1-------------------xx
# ...
# xx-------------------Page #2-------------------xx
# ...
# xx-------------------Page #3-------------------xx
# ...
# xx-------------------Page #4-------------------xx
# ...

# %% [markdown]
# # Test Data

# %% [markdown]
# ## Sarees

# %%
url_saree2='https://www.flipkart.com/search?q=sarees&sid=clo%2C8on%2Czpd%2C9og&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=sarees%7CWomen%27s+Sarees&requestId=15bd07b0-79be-4ec3-973a-fed00983b66a'
driver.get(url_saree2)

# %%
for page in range(3):
    sleep(3)
    url1 = []
    tags = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')
    sleep(1)
    for tag in tags:
        img_link= tag.get_attribute('src') 
        if tag is not None:
            if(img_link[0:4] == 'http'):
                url1.append(img_link)
    
    print(f"xx-------------------Page #{page+1}-------------------xx")
    
    for i in range(len(url1)):
        if i>=40:
            break
        response=requests.get(url1[i])
        file=open(r"C:\Users\utsav\Desktop\datatrained\internship\Assignment 13\test\saree "+str(page+1)+str(i)+".jpg","wb")
        file.write(response.content)
        print(f"Downloading Image #{i}")
        time.sleep(1.5)
    
        
    try:
        btn=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        btn.click()
    except NoSuchElementException:
        pass
        time.sleep(1)
# Out:
# xx-------------------Page #1-------------------xx
# ...
# xx-------------------Page #2-------------------xx
# ...
# xx-------------------Page #3-------------------xx
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13536/342582326.py in <module>
#      19         file.write(response.content)
#      20         print(f"Downloading Image #{i}")
# ---> 21         time.sleep(1.5)
#      22
#      23
#
# KeyboardInterrupt:

# %% [markdown]
# ## Trousers (men)

# %%
url_saree2='https://www.flipkart.com/search?q=trousers%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
driver.get(url_saree2)

# %%
for page in range(3):
    sleep(3)
    url2 = []
    tags = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')
    sleep(1)
    for tag in tags:
        img_link= tag.get_attribute('src') 
        if tag is not None:
            if(img_link[0:4] == 'http'):
                url2.append(img_link)
    
    print(f"xx-------------------Page #{page+1}-------------------xx")
    
    for i in range(len(url2)):
        if i>=40:
            break
        response=requests.get(url2[i])
        file=open(r"C:\Users\utsav\Desktop\datatrained\internship\Assignment 13\test\trouser "+str(page+1)+str(i)+".jpg","wb")
        file.write(response.content)
        print(f"Downloading Image #{i}")
        time.sleep(1.5)
    
        
    try:
        btn=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        btn.click()
    except NoSuchElementException:
        pass
        time.sleep(1)
# Out:
# xx-------------------Page #1-------------------xx
# ...
# xx-------------------Page #2-------------------xx
# ...
# xx-------------------Page #3-------------------xx
# ...

# %% [markdown]
# ## Jeans (men)

# %%
driver.get("https://www.flipkart.com/search?q=jeans%20for%20men&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off")

# %%
for page in range(3):
    sleep(3)
    url3 = []
    tags = driver.find_elements_by_xpath('//img[@class="_2r_T1I"]')
    sleep(1)
    for tag in tags:
        img_link= tag.get_attribute('src') 
        if tag is not None:
            if(img_link[0:4] == 'http'):
                url3.append(img_link)
    
    print(f"xx-------------------Page #{page+1}-------------------xx")
    
    for i in range(len(url3)):
        if i>=40:
            break
        response=requests.get(url3[i])
        file=open(r"C:\Users\utsav\Desktop\datatrained\internship\Assignment 13\test\jeans "+str(page+1)+str(i)+".jpg","wb")
        file.write(response.content)
        print(f"Downloading Image #{i}")
        time.sleep(1.5)
            
    try:
        btn=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
        btn.click()
    except NoSuchElementException:
        pass
        time.sleep(1)
# Out:
# xx-------------------Page #1-------------------xx
# ...
# xx-------------------Page #2-------------------xx
# ...
# xx-------------------Page #3-------------------xx
# ...
