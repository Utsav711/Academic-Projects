# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
from selenium.webdriver.common.by import By
from time import sleep 
from selenium.webdriver.support.wait import WebDriverWait as wait
import numpy as np
import pandas as pd
import warnings 
warnings.filterwarnings('ignore')
import urllib
import os
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Firefox()

# %% [markdown]
# # Flipkart Products

# %%
ratings=[]
review=[]
prod=[]

# %%
ratings1=[]
review1=[]
prod1=[]

# %% [markdown]
# ## Mobiles

# %%
url_mob={"https://www.flipkart.com/samsung-galaxy-f12-sky-blue-64-gb/product-reviews/itm0319ce24f74aa?pid=MOBGFG79BVGDHGWV&lid=LSTMOBGFG79BVGDHGWVGF2CRI&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
        "https://www.flipkart.com/redmi-9i-midnight-black-64-gb/product-reviews/itm9e3af42cbac00?pid=MOBFV8RYKWQ3HACE&lid=LSTMOBFV8RYKWQ3HACE8DXISG&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
        "https://www.flipkart.com/realme-8-cyber-silver-128-gb/product-reviews/itm63bda3bf5b1db?pid=MOBGYV98YXYYAFKN&lid=LSTMOBGYV98YXYYAFKNATWWNA&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
        "https://www.flipkart.com/motorola-g60-frosted-champagne-128-gb/product-reviews/itm9154ecfab780b?pid=MOBFWSF8KAWGYV9A&lid=LSTMOBFWSF8KAWGYV9ABTQCZJ&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"}

# %%
for url in url_mob:
    driver.get(url)
    
    for page in range(0,40): 
        for tag in driver.find_elements_by_xpath(
        "//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']"):
            ratings.append(tag.text)
            prod.append("Mobile phone")

        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #read more button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
#         wait(driver, 5).until(EC.element_to_be_clickable((By.XPATH,"//a[@class='_1arVWX']")))
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (1488, 1488, 1488)

# %%
review
# Out:
# ['Good 🤠🤠🤠',
#  'Good',
#  'Good delivery and product',
#  'Nice',
#  'Nice 👍',
#  'very good service from flipcart & redmi 9 i very good Mobile',
#  'great',
#  'Very very nice👌👌👌',
#  'Good',
#  'Nice Phone All Feature Are Good In price Rate..... 👍',
#  'Nice',
#  'Okay',
#  'Good',
#  'Good',
#  'I like it',
#  'Good one',
#  'Very good product but finger print not available Mobile is good',
#  'Good',
#  'Worth buying for normal usage.',
#  'Good',
#  'Good product at affordable price...',
#  'Mobile is good but camera is not that good',
#  'Easy to carry and battery backup',
#  'All good',
#  'Ok good',
#  'Amazing good product',
#  'Very good',
#  'Good',
#  'Good enough for medium use like for age above 40 year',
#  "Super redmi mobile it's very nice... Tq u flipkart ...",
#  'Very nice product.',
#  'Good app',
#  'Overall a gudone device.... value for money.. highly recommend it..if you are on a tight budget.',
#  'My mom using this phone.best phone for lite users',
# ...

# %%
ratings
# Out:
# ['4',
#  '4',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '4',
#  '4',
#  '4',
#  '5',
#  '3',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '4',
#  '5',
#  '3',
#  '5',
#  '5',
#  '4',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '4',
#  '4',
#  '4',
#  '5',
#  '4',
#  '5',
#  '3',
#  '3',
#  '3',
#  '5',
#  '3',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '4',
#  '4',
#  '5',
#  '4',
#  '5',
#  '4',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '4',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '3',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '5',
#  '5',
#  '5',
#  '5',
#  '5',
#  '4',
#  '3',
#  '5',
#  '5',
# ...

# %%
prod
# Out:
# ['Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
#  'Mobile phone',
# ...

# %% [markdown]
# ## Laptops

# %%
url_lap={"https://www.flipkart.com/acer-aspire-7-core-i5-10th-gen-8-gb-512-gb-ssd-windows-10-home-4-graphics-nvidia-geforce-gtx-1650-a715-75g-50ta-a715-75g-41g-a715-75g-52aa-gaming-laptop/product-reviews/itm365d5a348ad9c?pid=COMG2KBG2K4GFFF7&lid=LSTCOMG2KBG2K4GFFF78YBPHO&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
"https://www.flipkart.com/asus-celeron-dual-core-4-gb-1-tb-hdd-windows-10-home-x543ma-gq1015t-laptop/product-reviews/itmf8811674edbeb?pid=COMFSKF9UQH8RKYF&lid=LSTCOMFSKF9UQH8RKYFK8UKIL&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
"https://www.flipkart.com/apple-2020-macbook-air-m1-8-gb-256-gb-ssd-mac-os-big-sur-mgn63hn-a/product-reviews/itmde54f026889ce?pid=COMFXEKMGNHZYFH9&lid=LSTCOMFXEKMGNHZYFH9EOWT4E&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"}

# %%
for url in url_lap:
#     sleep(2)
#     wait(driver, 5).until(EC.element_to_be_clickable((By.XPATH,"//a[@class='_1arVWX']")))
    driver.get(url)
    
    for page in range(0,40): 
        for tag in driver.find_elements_by_xpath(
        "//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']"):
            ratings.append(tag.text)
            prod.append("Laptop")

        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #"read more" button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
#         wait(driver, 5).until(EC.element_to_be_clickable((By.XPATH,"//a[@class='_1arVWX']")))
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (2280, 2280, 2280)

# %% [markdown]
# ## Headphones

# %%
url_head={"https://www.flipkart.com/realme-buds-wireless-2-dart-charge-active-noise-cancellation-anc-bluetooth-headset/product-reviews/itm6e326a3e4bce4?pid=ACCG4WXWSQWWT9X2&lid=LSTACCG4WXWSQWWT9X21OAZTL&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"
          ,"https://www.flipkart.com/oneplus-bullets-wireless-z-bass-bluetooth-headset/product-reviews/itmc804703e0785e?pid=ACCFVA3KZ2EYMYX3&lid=LSTACCFVA3KZ2EYMYX3C5TCKH&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
          "https://www.flipkart.com


        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #"read more" button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (13399, 13399, 13399)

# %% [markdown]
# ## Router

# %%
url_rout={
    "https://www.flipkart.com/tp-link-tl-wr840n-wi-fi-300-mbps-wireless-router/product-reviews/itm3fc8c8aa6cb89?pid=RTREDWYNBGRFF6SX&lid=LSTRTREDWYNBGRFF6SXFSMTA3&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/tenda-f3-wireless-router-300-mbps/product-reviews/itmebg9ccwkmt4zs?pid=RTREBG9CJ7HHSHGJ&lid=LSTRTREBG9CJ7HHSHGJJ940LU&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/d-link-dir-819-750-mbps-wireless-router/product-reviews/itmff2hynmhzhtqa?pid=RTRFF2HYYUYHCGGK&lid=LSTRTRFF2HYYUYHCGGKB3BKOG&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/mi-r4cm-300-mbps-router/product-reviews/itm4ed0ab10f43e5?pid=RTRFZ9XMNKDBSHCY&lid=LSTRTRFZ9XMNKDBSHCY2N0IPP&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    }

# %%
for url in url_rout:
    driver.get(url)
    
    for page in range(0,40): 
        target = driver.find_element_by_link_text('NEXT')
        driver.execute_script('arguments[0].scrollIntoView(true);', target)
        sleep(0.25)
        for tag in driver.find_elements_by_xpath(
        "//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']"):
            ratings.append(tag.text)
            prod.append("Router")

        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #"read more" button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (14999, 14999, 14999)

# %% [markdown]
# ## Keyboard

# %%
url_key={
    "https://www.flipkart.com/dell-km117-keyboard-mouse-combo-wireless-laptop/product-reviews/itm3c041a41d7ce6?pid=ACCEPB2FWAVBFTEX&lid=LSTACCEPB2FWAVBFTEXSXZHRL&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/zebronics-zeb-k20-wired-usb-desktop-keyboard/product-reviews/itmfdkc4x6by3hte?pid=ACCFDK469A9W96HJ&lid=LSTACCFDK469A9W96HJQP3GD0&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/hp-100-wired-usb-desktop-keyboard/product-reviews/itmfbzgvfvmdhtgg?pid=ACCFBZGVBKU3MNFY&lid=LSTACCFBZGVBKU3MNFYN724KG&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/logitech-k230-space-saving-design-2-year-battery-life-wireless-laptop-keyboard/product-reviews/itm06406368c7f27?pid=ACCDEE5SFBX9WRRQ&lid=LSTACCDEE5SFBX9WRRQHICJPE&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"
}

# %%
for url in url_key:
    driver.get(url)
    
    for page in range(0,40): 
        target = driver.find_element_by_link_text('NEXT')
        driver.execute_script('arguments[0].scrollIntoView(true);', target)
        sleep(0.25)
        for tag in driver.find_elements_by_xpath(
        "//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']"):
            ratings.append(tag.text)
            prod.append("Keyboard")

        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #"read more" button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (16587, 16587, 16587)

# %% [markdown]
# ## External Hard Disk

# %%
url_disk={
    "https://www.flipkart.com/wd-my-passport-1-tb-external-hard-disk-drive/product-reviews/itm49af26ca1ad50?pid=ACCFH7XCF2FAQQ2A&lid=LSTACCFH7XCF2FAQQ2APHKVSD&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/seagate-ultra-touch-2-tb-external-hard-disk-drive/product-reviews/itm575cf91112957?pid=ACCFFUEQ4UKGTNRC&lid=LSTACCFFUEQ4UKGTNRCTHK9YO&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/toshiba-canvio-ready-1-tb-wired-external-hard-disk-drive/product-reviews/itmf4kqhbpyhhzdd?pid=ACCF4KQHKQ5Y9P5B&lid=LSTACCF4KQHKQ5Y9P5BBPMLZX&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"
    "https://www.flipkart.com/samsung-t5-1-tb-external-solid-state-drive/product-reviews/itmezny8gfpxgh2a?pid=ACCEZNY8QCFXPBXH&lid=LSTACCEZNY8QCFXPBXHT3LQWE&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/wd-elements-1-tb-wired-external-hard-disk-drive/product-reviews/itmf5ga7wtjddk25?pid=ACCF5GA7ASHY6XFX&lid=LSTACCF5GA7ASHY6XFXOFRKM6&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"
}

# %%
for url in url_disk:
    driver.get(url)
    
    for page in range(0,40): 
        target = driver.find_element_by_link_text('NEXT')
        driver.execute_script('arguments[0].scrollIntoView(true);', target)
        sleep(0.25)
        for tag in driver.find_elements_by_xpath(
        "//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']"):
            ratings.append(tag.text)
            prod.append("External Hard Disk")

        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #"read more" button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (18186, 18186, 18186)

# %%
ratings=ratings[:18186]
review=review[:18186]
prod=prod[:18186]

# %% [markdown]
# ## Memory card

# %%
url_mem={
    "https://www.flipkart.com/samsung-evo-plus-32-gb-sd-card-class-10-95-mb-s-memory/product-reviews/itmet6zfpfezjpbs?pid=ACCET6ZFCGEG7GZE&lid=LSTACCET6ZFCGEG7GZE0E1UDH&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/sandisk-ultra-64-microsdxc-class-10-120-mbps-memory-card/product-reviews/itm576cae9eeee18?pid=ACCFXNGY9XTRPMCH&lid=LSTACCFXNGY9XTRPMCHIJVMTL&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/hp-u1-32-gb-microsdhc-class-10-100-mb-s-memory-card/product-reviews/itmf5zyf6eyzwxvf?pid=ACCF5ZYFVZYTX6ZJ&lid=LSTACCF5ZYFVZYTX6ZJSLVXXE&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"
}

# %%
for url in url_mem:
    driver.get(url)
    
    for page in range(0,60): 
        target = driver.find_element_by_link_text('NEXT')
        driver.execute_script('arguments[0].scrollIntoView(true);', target)
        sleep(0.25)
        for tag in driver.find_elements_by_xpath(
        "//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']"):
            ratings.append(tag.text)
            prod.append("Memory card")

        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #"read more" button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (19698, 19698, 19698)

# %% [markdown]
# ## Bluetooth Speaker

# %%
url_speak={
    "https://www.flipkart.com/boat-stone-grenade-5-w-portable-bluetooth-speaker/product-reviews/itm201b0f67d55cb?pid=ACCFDBFR9ZCZTDGJ&lid=LSTACCFDBFR9ZCZTDGJUKDA7E&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/f-ferons-wireless-rechargeable-portable-premium-dj-bass-multimedia-ffr-artg-113-9-w-bluetooth-speaker/product-reviews/itmd7578d0475ba1?pid=ACCFW659GH5DZBHT&lid=LSTACCFW659GH5DZBHT6WOPKU&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/zebronics-zeb-vita-plus-16-w-bluetooth-laptop-desktop-speaker/product-reviews/itm122fb339af89d?pid=ACCFNDTWZD3UZGTH&lid=LSTACCFNDTWZD3UZGTHI9FREK&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/mivi-play-5-w-portable-bluetooth-speaker/product-reviews/itm9dcdfcd2431db?pid=ACCG25T3Z4CHBUAP&lid=LSTACCG25T3Z4CHBUAPJX3A8A&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT",
    "https://www.flipkart.com/infinity-harman-fuze-99-4-5-w-bluetooth-speaker/product-reviews/itm769914305b02a?pid=ACCFN5HBZRGKGFMA&lid=LSTACCFN5HBZRGKGFMABTKCRM&aid=overall&certifiedBuyer=false&sortOrder=MOST_RECENT"
}

# %%
for url in url_speak:
    driver.get(url)
    
    for page in range(0,40): 
        target = driver.find_element_by_link_text('NEXT')
        driver.execute_script('arguments[0].scrollIntoView(true);', target)
        sleep(0.25)
        for tag in driver.find_elements_by_xpath(
        "//div[@class='_3LWZlK _1BLPMq' or @class='_3LWZlK _1rdVr6 _1BLPMq' or @class='_3LWZlK _32lA32 _1BLPMq']"):
            ratings.append(tag.text)
            prod.append("Bluetooth Speaker")

        for k in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
            try: 
                btn=driver.find_element_by_xpath("//span[@class='_1BWGvX']") #"read more" button in review section if present
                btn.click()
            except:
                pass
            review.append(k.text.replace('\n',' '))

        try:
            button=driver.find_element_by_xpath("//*[contains(text(), 'Next')]")
            driver.execute_script("arguments[0].click();", button)
        except NoSuchElementException:
            pass
        sleep(2)

# %%
len(review),len(prod),len(ratings)
# Out:
# (20645, 20645, 20645)

# %%
df=pd.DataFrame({"Product":prod,"Review":review,"Rating":ratings})

# %%
df.iloc[9870]
# Out:
# Product               Powerbank
# Review     Nice 👍👍 good quality
# Rating                        5
# Name: 9870, dtype: object

# %%
df
# Out:
#                  Product                                             Review  \
# 0           Mobile phone                                        Good mobile
# 1           Mobile phone                                               Good
# 2           Mobile phone                                               Good
# 3           Mobile phone                                        Nice mobile
# 4           Mobile phone                                          Very good
# ...                  ...                                                ...
# 20640  Bluetooth Speaker        Sound clear bass normal bass value of money
# 20641  Bluetooth Speaker       Its very poor quality don't Waste your money
# 20642  Bluetooth Speaker  Very good sound quality I like it and very cle...
# 20643  Bluetooth Speaker                 Nice product in this price range .
# 20644  Bluetooth Speaker  It's nice. But I'd advise to add some money an...
#
#       Rating
# 0          4
# 1          4
# ...

# %%
df.to_csv("Ratings_mined.csv")

# %%
driver.close()
